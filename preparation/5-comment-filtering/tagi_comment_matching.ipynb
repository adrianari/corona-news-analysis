# %%
import pymysql as mariadb
import pandas as pd
import matplotlib
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
import random
from sklearn.cluster import KMeans
import re
from wordcloud import WordCloud
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /home/adriana/snap/jupyter/common/lib/python3.7/site-packages/joblib/_multiprocessing_helpers.py:45: UserWarning: [Errno 13] Permission denied.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %%
connection = mariadb.connect(
    host="localhost",
#    database="masterarbeit",    
#    user="user",
#    password="password"
)

sql = ("SELECT * "
       "FROM artikel "
       "WHERE newsoutlet = 'tagi'")

df_artikel = pd.read_sql_query(sql, connection)

# %%
df2 = df_artikel
df2 = df2.drop(columns = ["title", "lead", "time", "author", "article_text", "cat_given2", "cat_given1", "newsoutlet"])

# %%
df2 = df2.set_index("url")

# %%
#connecting to commentaires
sql2 = ("SELECT * "
       "FROM kommentare "
       "WHERE outlet = 'tagi'")

df1 = pd.read_sql_query(sql2, connection)
df1 = df1.set_index("url")

# %%
df3 = df1.join(df2, how="inner")
#df3 = df3.drop(columns = ["kom_datum", "kom_zeit"])
#df3 = df3.set_index("url")

# %%
df3 = df3.drop([0], axis = 1)
df3
# Out:
#                                                                                                     1  \
# https://www.tagesanzeiger.ch/100-milliarden-pak...  Die EU kann mit labern nicht viel anfangen, It...
# https://www.tagesanzeiger.ch/100-milliarden-pak...  Italien ist verloren. Für die bereits fest ver...
# https://www.tagesanzeiger.ch/100-milliarden-pak...  @Hans Züllig «Italien ist verloren». …Nicht nu...
# https://www.tagesanzeiger.ch/100-milliarden-pak...  Wer seine Landsleute mit 56-62 Jahren in Rente...
# https://www.tagesanzeiger.ch/100-milliarden-pak...  @Wolfgang Blanck Es gibt nicht wirklich eine p...
# ...                                                                                               ...
# https://www.tagesanzeiger.ch/zweiter-covid-impf...  Interessant zu wissen wäre die Altergruppe(n) ...
# https://www.tagesanzeiger.ch/zweiter-covid-impf...  @Urs Mettler Das ist ein bekanntes Problem bei...
# https://www.tagesanzeiger.ch/zweiter-covid-impf...  @Urs Mettler Und mehrheitlich in einem Umfeld ...
# https://www.tagesanzeiger.ch/zweiter-covid-impf...  @Fabio Hasler Gute erforschten Impfstoff bei I...
# https://www.tagesanzeiger.ch/zwischen-den-zeile...  Warum liegt es an den Hinterbliebenen, die  ei...
#
#                                                              2   3     4  5  \
# https://www.tagesanzeiger.ch/100-milliarden-pak...  2020-05-04 NaN  tagi  0
# https://www.tagesanzeiger.ch/100-milliarden-pak...  2020-04-04 NaN  tagi  5
# https://www.tagesanzeiger.ch/100-milliarden-pak...  2020-04-04 NaN  tagi  5
# https://www.tagesanzeiger.ch/100-milliarden-pak...  2020-03-04 NaN  tagi  2
# https://www.tagesanzeiger.ch/100-milliarden-pak...  2020-05-04 NaN  tagi  0
# ...                                                        ...  ..   ... ..
# https://www.tagesanzeiger.ch/zweiter-covid-impf...  2020-11-16 NaN  tagi  0
# https://www.tagesanzeiger.ch/zweiter-covid-impf...  2020-11-16 NaN  tagi  0
# https://www.tagesanzeiger.ch/zweiter-covid-impf...  2020-11-16 NaN  tagi  0
# https://www.tagesanzeiger.ch/zweiter-covid-impf...  2020-11-16 NaN  tagi  0
# https://www.tagesanzeiger.ch/zwischen-den-zeile...  2020-12-18 NaN  tagi  4
#
#                                                      6    7        date
# https://www.tagesanzeiger.ch/100-milliarden-pak... NaN   88  2020-02-04
# https://www.tagesanzeiger.ch/100-milliarden-pak... NaN  477  2020-02-04
# https://www.tagesanzeiger.ch/100-milliarden-pak... NaN  689  2020-02-04
# https://www.tagesanzeiger.ch/100-milliarden-pak... NaN  741  2020-02-04
# https://www.tagesanzeiger.ch/100-milliarden-pak... NaN  296  2020-02-04
# ...                                                 ..  ...         ...
# https://www.tagesanzeiger.ch/zweiter-covid-impf... NaN  111  2020-11-16
# https://www.tagesanzeiger.ch/zweiter-covid-impf... NaN  357  2020-11-16
# https://www.tagesanzeiger.ch/zweiter-covid-impf... NaN   97  2020-11-16
# https://www.tagesanzeiger.ch/zweiter-covid-impf... NaN  369  2020-11-16
# https://www.tagesanzeiger.ch/zwischen-den-zeile... NaN  301  2020-12-16
#
# [70274 rows x 8 columns]

# %%
df3 = df3.sort_values(by="date")

# %%
df3.to_csv("tagi_kom_fin.csv", index= True, sep = "|", header = None)
