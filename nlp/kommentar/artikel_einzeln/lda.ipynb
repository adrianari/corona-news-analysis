# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans


# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel


import pymysql as mariadb
import pickle
from sklearn.decomposition import PCA

# Plotting tools
import pyLDAvis 
import pyLDAvis.gensim_models
import matplotlib.pyplot as plt
# %matplotlib inline
import bokeh
from bokeh.models import Circle, ColumnDataSource, Line, LinearAxis, Range1d, LabelSet, HoverTool
from bokeh.palettes import d3
import bokeh.models as bmo
from bokeh.plotting import figure, output_file, show
from bokeh.core.properties import value
from bokeh.palettes import viridis
from bokeh.palettes import inferno
# Out:
# /home/adriana/snap/jupyter/common/lib/python3.7/site-packages/joblib/_multiprocessing_helpers.py:45: UserWarning: [Errno 13] Permission denied.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=False))  # deacc=True removes punctuations
        
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

a = "-2hj-"     #kürzel für betrachteten zeitraum
b = 13          #anzahl cluster
c = [8,3,5,5,4,5,3,3,6,5,3,5,4]   #anzahl topics

# %%
stop_words = stopwords.words('german')
stop_words.extend(["wieultimativwir", "vernetztsind","dassinder","buchauszug","wirbeispielhaft","diewie", 
                   "bild_watson", "dialogfensters","dialogfensters", "this_is", "modal_window" , "esc_brechen"])

# %%
#establishing the dataframe
connection = mariadb.connect(host="localhost", database="masterarbeit",
                            user="USER", password="PASSWORD")

#getting data
sql = ("SELECT * "
       "FROM comment ")

df = pd.read_sql_query(sql, connection)

liste = pickle.load(open("lemmatized_kom.pkl", "rb"))

df["lemmatized"] = liste

# %%
df['art_date'] = pd.to_datetime(df['art_date'])
df2 = df
df2 = df2.set_index(df2["art_date"])
df2 = df2[df2.index.month.isin([1,2,3,4,5,6])]
df = df2

# %%
#vectorizer
vectorizer = TfidfVectorizer(max_features = 3000)
vecs = vectorizer.fit_transform(df["lemmatized"])

kmeansmodel = KMeans(n_clusters = b, random_state=42).fit(vecs)
df["labels"] = kmeansmodel.labels_
df3 = df.groupby(['labels', 'cat_res1'])['labels'].count()
df3.to_csv("komm"+str(b)+"_clustered.csv", sep = ";")

# %%
pca = PCA(n_components=2)
pca_2d = np.array(pca.fit_transform(vecs.todense()))

# %%
df["labels"] = df["labels"].astype(str)
source = ColumnDataSource(data=dict(x=pca_2d[:,0], 
                                    y=pca_2d[:,1], 
                                    label_field1=df['cat_res1'],
                                    label_field2=df['labels'],
                                    keys=df['labels']))

hover = HoverTool(tooltips=[("ressort", "@label_field1"), ('label', '@label_field2')])
palette = inferno(len(df['labels'].unique()))
color_map = bmo.CategoricalColorMapper(factors=df['labels'].unique(), palette=palette)
TOOLS = ['pan', 'wheel_zoom', 'reset', hover]
p_pca = figure(title='Graphic representation of the clustering', tools=TOOLS, toolbar_location="left")
p_pca.scatter(x='x', 
              y='y', 
              size=2, 
              source=source,
              color={'field': 'keys', 'transform': color_map},
              legend_field='keys')

output_file("clustered-kom"+str(a)+".html")
show(p_pca)

# %%
clusters = [x for x in range(b)]
num_subtopics = c

# %%
for x in clusters:
    df4 = df.loc[df['labels'] == str(x)]

    data_words = list(sent_to_words(df4["lemmatized"]))

    bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100)
    bigram_mod = gensim.models.phrases.Phraser(bigram)

    data_words_nostops = remove_stopwords(data_words)
    data_words_bigrams = make_bigrams(data_words_nostops)

# Create Dictionary
    id2word = corpora.Dictionary(data_words_bigrams)

# Create Corpus
    texts = data_words_bigrams

# Term Document Frequency
    corpus = [id2word.doc2bow(text) for text in texts]

# View
    lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                               id2word=id2word,
                                               num_topics=num_subtopics[clusters.index(x)], 
                                               random_state=42,
                                               update_every=1,
                                               chunksize=100,
                                               passes=10,
                                               alpha='auto',
                                               per_word_topics=True
                                               )

    
    vis = pyLDAvis.gensim_models.prepare(lda_model, corpus, id2word, R = 15, sort_topics = False)
    pyLDAvis.save_html(vis, str(x)+"-comment-cluster" + str(a) + "lda.html")
    
    print("\n")
    print("LDA for Cluster No. ", x, " likely containing ", num_subtopics[clusters.index(x)], " subtopics with a perplexity of ", lda_model.log_perplexity(corpus))
    pprint(lda_model.print_topics())
    doc_lda = lda_model[corpus]
# Out:
# LDA for Cluster No.  0  likely containing  8  subtopics with a perplexity of  -9.918825644638748
# [(0,
#   '0.044*"einfach" + 0.027*"menschen" + 0.017*"denken" + 0.016*"natürlich" + '
#   '0.016*"dafür" + 0.016*"lassen" + 0.016*"fälle" + 0.014*"letzt" + '
#   '0.013*"tage" + 0.009*"ca"'),
#  (1,
#   '0.030*"mal" + 0.023*"kommen" + 0.019*"immer" + 0.018*"zahlen" + '
#   '0.017*"wenig" + 0.016*"massnahmen" + 0.016*"ganz" + 0.016*"genau" + '
#   '0.015*"leute" + 0.011*"sollen"'),
#  (2,
#   '0.040*"schon" + 0.035*"gehen" + 0.028*"corona" + 0.021*"sehen" + '
#   '0.017*"sagen" + 0.017*"wohl" + 0.015*"finden" + 0.012*"eigentlich" + '
#   '0.012*"lang" + 0.011*"warum"'),
#  (3,
#   '0.037*"covid" + 0.028*"nehmen" + 0.028*"nein" + 0.021*"tot" + '
#   '0.019*"liegen" + 0.018*"tag" + 0.018*"brauchen" + 0.013*"wissen" + '
#   '0.013*"land" + 0.011*"je"'),
#  (4,
#   '0.035*"mehr" + 0.014*"müssen" + 0.013*"ja" + 0.013*"dürfen" + 0.012*"virus" '
#   '+ 0.010*"danke" + 0.010*"beim" + 0.010*"leider" + 0.010*"gut" + '
#   '0.009*"gar"'),
#  (5,
#   '0.020*"lesen" + 0.018*"bleiben" + 0.017*"halten" + 0.016*"zürich" + '
#   '0.014*"sprechen" + 0.014*"neu" + 0.013*"schreiben" + 0.012*"treffen" + '
#   '0.012*"scheinen" + 0.012*"gleich"'),
#  (6,
#   '0.052*"schweiz" + 0.021*"stehen" + 0.019*"vielleicht" + 0.016*"testen" + '
#   '0.014*"sogar" + 0.013*"gerade" + 0.013*"alt" + 0.012*"tests" + 0.012*"bund" '
#   '+ 0.012*"kanton"'),
#  (7,
#   '0.028*"hoch" + 0.022*"wirklich" + 0.018*"heute" + 0.017*"problem" + '
#   '0.016*"sichern" + 0.015*"positiv" + 0.014*"personen" + 0.014*"falsch" + '
#   '0.013*"quarantäne" + 0.013*"jahr"')]
#
#
# LDA for Cluster No.  1  likely containing  3  subtopics with a perplexity of  -7.968602831337396
# [(0,
#   '0.098*"impfen" + 0.044*"lassen" + 0.013*"schon" + 0.012*"ja" + 0.009*"mal" '
#   '+ 0.009*"menschen" + 0.009*"gehen" + 0.008*"mehr" + 0.008*"wer" + '
#   '0.008*"sollen"'),
#  (1,
#   '0.014*"alt" + 0.013*"finden" + 0.008*"natürlich" + 0.008*"bereits" + '
#   '0.008*"schnellen" + 0.007*"bald" + 0.007*"beim" + 0.006*"halt" + '
#   '0.006*"pandemie" + 0.006*"millionen"'),
#  (2,
#   '0.035*"impfung" + 0.018*"impfstoff" + 0.011*"virus" + 0.011*"grippe" + '
#   '0.008*"fragen" + 0.008*"wohl" + 0.007*"mehr" + 0.007*"gut" + 0.007*"geben" '
#   '+ 0.007*"möglich"')]
#
#
# LDA for Cluster No.  2  likely containing  5  subtopics with a perplexity of  -9.250811270290122
# [(0,
#   '0.022*"mehr" + 0.021*"gehen" + 0.017*"schon" + 0.015*"mal" + '
#   '0.015*"einfach" + 0.015*"immer" + 0.013*"finden" + 0.013*"ja" + '
#   '0.011*"kommen" + 0.009*"geben"'),
#  (1,
#   '0.019*"verstehen" + 0.019*"glauben" + 0.013*"wissen" + 0.012*"gar" + '
#   '0.011*"herr" + 0.011*"bitte" + 0.010*"arbeiten" + 0.010*"bleiben" + '
#   '0.010*"halt" + 0.008*"anstecken"'),
#  (2,
#   '0.021*"gut" + 0.015*"massnahmen" + 0.015*"ganz" + 0.014*"leben" + '
#   '0.013*"sehen" + 0.012*"menschen" + 0.011*"genau" + 0.010*"schweiz" + '
#   '0.009*"weiss" + 0.008*"zahlen"'),
#  (3,
#   '0.023*"lesen" + 0.012*"bundesrat" + 0.011*"kommentar" + 0.010*"quarantäne" '
#   '+ 0.009*"gleich" + 0.009*"schauen" + 0.008*"regeln" + 0.007*"familie" + '
#   '0.007*"ferien" + 0.007*"schnellen"'),
#  (4,
#   '0.015*"darum" + 0.012*"alt" + 0.010*"jahre" + 0.010*"wochen" + 0.010*"nein" '
#   '+ 0.009*"ab" + 0.008*"scheinen" + 0.008*"darauf" + 0.007*"woche" + '
#   '0.007*"geld"')]
#
#
# LDA for Cluster No.  3  likely containing  5  subtopics with a perplexity of  -9.146814592092053
# [(0,
#   '0.017*"fragen" + 0.016*"hoch" + 0.013*"leben" + 0.013*"möglich" + '
#   '0.012*"sterben" + 0.008*"wegen" + 0.008*"paar" + 0.008*"alt" + 0.008*"all" '
#   '+ 0.007*"liegen"'),
#  (1,
#   '0.013*"vielleicht" + 0.013*"dürfen" + 0.010*"halt" + 0.009*"nie" + '
#   '0.008*"wochen" + 0.008*"lesen" + 0.008*"ch" + 0.008*"absolut" + '
#   '0.008*"land" + 0.008*"daran"'),
#  (2,
#   '0.017*"mehr" + 0.016*"schon" + 0.012*"ja" + 0.012*"mal" + 0.012*"gehen" + '
#   '0.012*"einfach" + 0.010*"immer" + 0.010*"massnahmen" + 0.010*"gut" + '
#   '0.010*"wenig"'),
#  (3,
#   '0.013*"testen" + 0.012*"gar" + 0.011*"positiv" + 0.010*"lassen" + '
#   '0.010*"wichtig" + 0.009*"falsch" + 0.009*"beim" + 0.009*"lockdown" + '
#   '0.008*"aussagen" + 0.008*"quarantäne"'),
#  (4,
#   '0.033*"warum" + 0.029*"eher" + 0.015*"bitte" + 0.015*"kinder" + '
#   '0.010*"schaffen" + 0.010*"gesund" + 0.009*"erreichen" + 0.008*"erwarten" + '
#   '0.008*"zwingen" + 0.007*"darüber"')]
#
#
# LDA for Cluster No.  4  likely containing  4  subtopics with a perplexity of  -8.733676288969598
# [(0,
#   '0.012*"finden" + 0.009*"mögen" + 0.008*"quarantäne" + 0.008*"niemand" + '
#   '0.007*"kennen" + 0.006*"gerne" + 0.005*"positiv" + 0.005*"darauf" + '
#   '0.005*"paar" + 0.005*"falsch"'),
#  (1,
#   '0.014*"verbreiten" + 0.013*"sichern" + 0.012*"krankheiten" + '
#   '0.012*"quatsch" + 0.011*"zweifeln" + 0.010*"amüsant" + 0.009*"covid" + '
#   '0.009*"meinung" + 0.008*"bag" + 0.007*"nie"'),
#  (2,
#   '0.082*"wer" + 0.016*"mehr" + 0.014*"weiss" + 0.013*"glauben" + '
#   '0.013*"geben" + 0.013*"schon" + 0.011*"heute" + 0.010*"gut" + 0.010*"immer" '
#   '+ 0.010*"kommen"'),
#  (3,
#   '0.079*"wer" + 0.016*"gehen" + 0.011*"sagen" + 0.011*"virus" + 0.010*"ja" + '
#   '0.010*"schon" + 0.009*"wissen" + 0.008*"leben" + 0.007*"denken" + '
#   '0.006*"dürfen"')]
#
#
# LDA for Cluster No.  5  likely containing  5  subtopics with a perplexity of  -8.921209805522157
# [(0,
#   '0.015*"stehen" + 0.014*"dürfen" + 0.011*"lassen" + 0.010*"covid" + '
#   '0.010*"situation" + 0.009*"masken" + 0.008*"schweizer" + 0.007*"jahr" + '
#   '0.007*"eher" + 0.007*"ch"'),
#  (1,
#   '0.017*"wohl" + 0.016*"genau" + 0.013*"klaren" + 0.011*"glauben" + '
#   '0.011*"welt" + 0.011*"leider" + 0.010*"heute" + 0.009*"lieb" + '
#   '0.008*"liegen" + 0.007*"kommentar"'),
#  (2,
#   '0.061*"gut" + 0.018*"kommen" + 0.015*"finden" + 0.014*"ganz" + '
#   '0.014*"massnahmen" + 0.011*"leute" + 0.010*"sichern" + 0.008*"natürlich" + '
#   '0.008*"danke" + 0.007*"halten"'),
#  (3,
#   '0.018*"geben" + 0.016*"müssen" + 0.011*"lang" + 0.011*"impfung" + '
#   '0.010*"idee" + 0.010*"beim" + 0.010*"impfstoff" + 0.009*"arbeiten" + '
#   '0.008*"gerade" + 0.007*"gleichen"'),
#  (4,
#   '0.152*"gut" + 0.019*"gehen" + 0.018*"ja" + 0.014*"schon" + 0.013*"schweiz" '
#   '+ 0.013*"wenig" + 0.012*"mehr" + 0.012*"mal" + 0.012*"immer" + '
#   '0.011*"einfach"')]
#
#
# LDA for Cluster No.  6  likely containing  3  subtopics with a perplexity of  -8.98082381499331
# [(0,
#   '0.014*"mehr" + 0.011*"sagen" + 0.010*"gehen" + 0.010*"genau" + 0.010*"gut" '
#   '+ 0.009*"mal" + 0.009*"kommen" + 0.008*"massnahmen" + 0.008*"schweiz" + '
#   '0.008*"eigentlich"'),
#  (1,
#   '0.015*"ja" + 0.011*"menschen" + 0.010*"sehen" + 0.009*"bitte" + '
#   '0.008*"dürfen" + 0.007*"covid" + 0.007*"halten" + 0.007*"daran" + '
#   '0.006*"wirklich" + 0.006*"sterben"'),
#  (2,
#   '0.015*"tun" + 0.013*"einfach" + 0.012*"corona" + 0.011*"geben" + '
#   '0.009*"virus" + 0.009*"leute" + 0.008*"lockdown" + 0.008*"fragen" + '
#   '0.007*"schon" + 0.006*"bringen"')]
#
#
# LDA for Cluster No.  7  likely containing  3  subtopics with a perplexity of  -8.277064552292371
# [(0,
#   '0.018*"maskenpflicht" + 0.007*"schweiz" + 0.007*"problem" + 0.007*"leute" + '
#   '0.006*"warum" + 0.006*"ab" + 0.006*"wirklich" + 0.006*"draussen" + '
#   '0.005*"läden" + 0.005*"gleichzeitig"'),
#  (1,
#   '0.098*"masken" + 0.012*"viren" + 0.011*"finden" + 0.010*"sagen" + '
#   '0.007*"nützen" + 0.007*"gar" + 0.007*"reduzieren" + 0.006*"studien" + '
#   '0.006*"somit" + 0.006*"derjenige"'),
#  (2,
#   '0.059*"maske" + 0.048*"tragen" + 0.012*"gehen" + 0.012*"abstand" + '
#   '0.011*"mehr" + 0.010*"ja" + 0.009*"menschen" + 0.009*"beim" + '
#   '0.009*"einfach" + 0.009*"halten"')]
#
#
# LDA for Cluster No.  8  likely containing  6  subtopics with a perplexity of  -9.418387198856498
# [(0,
#   '0.020*"kommen" + 0.017*"gut" + 0.015*"ja" + 0.015*"ganz" + 0.015*"müssen" + '
#   '0.014*"virus" + 0.013*"wohl" + 0.011*"finden" + 0.010*"problem" + '
#   '0.010*"genau"'),
#  (1,
#   '0.018*"geld" + 0.018*"heisst" + 0.015*"situation" + 0.014*"wert" + '
#   '0.014*"lesen" + 0.013*"lieb" + 0.013*"gelten" + 0.012*"jahre" + '
#   '0.011*"kennen" + 0.011*"länder"'),
#  (2,
#   '0.016*"sagen" + 0.014*"erst" + 0.013*"dürfen" + 0.013*"leben" + '
#   '0.012*"lassen" + 0.011*"tun" + 0.010*"wirklich" + 0.010*"zeigen" + '
#   '0.010*"seit" + 0.010*"hören"'),
#  (3,
#   '0.051*"schweiz" + 0.025*"kantone" + 0.023*"wirtschaft" + 0.016*"ab" + '
#   '0.015*"bund" + 0.015*"schweizer" + 0.014*"letzt" + 0.011*"maskenpflicht" + '
#   '0.011*"krise" + 0.010*"artikel"'),
#  (4,
#   '0.016*"dafür" + 0.015*"testen" + 0.014*"wegen" + 0.013*"fälle" + '
#   '0.012*"tests" + 0.011*"tage" + 0.011*"impfstoff" + 0.010*"paar" + '
#   '0.010*"personen" + 0.010*"deshalb"'),
#  (5,
#   '0.024*"mehr" + 0.021*"schon" + 0.019*"gehen" + 0.017*"einfach" + '
#   '0.016*"immer" + 0.014*"massnahmen" + 0.013*"mal" + 0.012*"wenig" + '
#   '0.012*"menschen" + 0.010*"corona"')]
# LDA for Cluster No.  9  likely containing  5  subtopics with a perplexity of  -9.271546848435953
# [(0,
#   '0.018*"ja" + 0.016*"mehr" + 0.015*"schon" + 0.014*"gehen" + 0.013*"gut" + '
#   '0.012*"immer" + 0.011*"mal" + 0.010*"einfach" + 0.008*"kommen" + '
#   '0.008*"schweiz"'),
#  (1,
#   '0.013*"halt" + 0.012*"dafür" + 0.010*"recht" + 0.009*"jahr" + 0.009*"lieb" '
#   '+ 0.009*"arbeiten" + 0.009*"gleichen" + 0.008*"schlecht" + 0.007*"kosten" + '
#   '0.007*"davon"'),
#  (2,
#   '0.020*"sollen" + 0.014*"eben" + 0.013*"warum" + 0.012*"zeit" + '
#   '0.012*"finden" + 0.010*"alt" + 0.009*"ab" + 0.009*"masken" + '
#   '0.008*"anstecken" + 0.008*"eigentlich"'),
#  (3,
#   '0.018*"klaren" + 0.014*"niemand" + 0.013*"hören" + 0.010*"überhaupt" + '
#   '0.009*"stimmen" + 0.009*"quarantäne" + 0.008*"de" + 0.008*"wieso" + '
#   '0.007*"schliessen" + 0.006*"fall"'),
#  (4,
#   '0.025*"massnahmen" + 0.021*"wenig" + 0.010*"wissen" + 0.009*"lassen" + '
#   '0.009*"trotzdem" + 0.009*"paar" + 0.008*"brauchen" + 0.008*"schweizer" + '
#   '0.008*"möglich" + 0.007*"geld"')]
#
#
# LDA for Cluster No.  10  likely containing  3  subtopics with a perplexity of  -8.344406350804112
# [(0,
#   '0.011*"präsidenten" + 0.010*"us" + 0.006*"politik" + 0.006*"hören" + '
#   '0.005*"the" + 0.005*"putin" + 0.005*"scheinen" + 0.005*"verschwinden" + '
#   '0.005*"stark" + 0.004*"treffen"'),
#  (1,
#   '0.016*"donald" + 0.014*"einfach" + 0.013*"geben" + 0.012*"mehr" + '
#   '0.011*"recht" + 0.010*"erst" + 0.007*"link" + 0.007*"trump" + '
#   '0.006*"menschen" + 0.006*"genau"'),
#  (2,
#   '0.118*"trump" + 0.013*"gut" + 0.012*"usa" + 0.011*"biden" + 0.011*"schon" + '
#   '0.009*"corona" + 0.008*"ja" + 0.008*"präsident" + 0.008*"glauben" + '
#   '0.007*"gehen"')]
#
#
# LDA for Cluster No.  11  likely containing  5  subtopics with a perplexity of  -8.903104548737629
# [(0,
#   '0.019*"wegen" + 0.015*"personen" + 0.014*"tot" + 0.010*"schlecht" + '
#   '0.010*"gleichen" + 0.009*"bitte" + 0.009*"daher" + 0.009*"stark" + '
#   '0.009*"genug" + 0.008*"test"'),
#  (1,
#   '0.013*"maskenpflicht" + 0.010*"ansteckungen" + 0.009*"woche" + 0.009*"pro" '
#   '+ 0.009*"völlig" + 0.007*"allerdings" + 0.007*"risiko" + 0.007*"zahl" + '
#   '0.006*"offen" + 0.006*"nämlich"'),
#  (2,
#   '0.072*"geben" + 0.016*"mehr" + 0.010*"ja" + 0.010*"schon" + 0.009*"immer" + '
#   '0.008*"einfach" + 0.008*"corona" + 0.007*"gut" + 0.007*"menschen" + '
#   '0.007*"massnahmen"'),
#  (3,
#   '0.038*"wenig" + 0.024*"ganz" + 0.016*"sichern" + 0.014*"fälle" + '
#   '0.010*"verstehen" + 0.010*"möglich" + 0.009*"artikel" + 0.008*"gerade" + '
#   '0.007*"stellen" + 0.007*"problem"'),
#  (4,
#   '0.020*"falsch" + 0.018*"positiv" + 0.017*"brauchen" + 0.015*"anstecken" + '
#   '0.012*"fall" + 0.010*"darauf" + 0.007*"herr" + 0.007*"svp" + '
#   '0.006*"weltweit" + 0.006*"kleine"')]
#
#
# LDA for Cluster No.  12  likely containing  4  subtopics with a perplexity of  -8.692127180674468
# [(0,
#   '0.011*"bereits" + 0.009*"patienten" + 0.008*"weit" + 0.008*"bekennen" + '
#   '0.008*"stellen" + 0.007*"lesen" + 0.007*"daher" + 0.007*"fast" + '
#   '0.006*"tage" + 0.006*"erste"'),
#  (1,
#   '0.010*"anstecken" + 0.009*"menschen" + 0.008*"wochen" + 0.007*"quarantäne" '
#   '+ 0.007*"dafür" + 0.006*"all" + 0.006*"wieso" + 0.006*"müssen" + '
#   '0.006*"darum" + 0.006*"schwer"'),
#  (2,
#   '0.120*"ja" + 0.013*"schon" + 0.012*"mehr" + 0.011*"gehen" + 0.009*"mal" + '
#   '0.008*"einfach" + 0.007*"immer" + 0.007*"ganz" + 0.007*"corona" + '
#   '0.007*"gut"'),
#  (3,
#   '0.015*"tun" + 0.013*"leider" + 0.011*"beim" + 0.009*"arbeiten" + '
#   '0.009*"meinung" + 0.007*"zurück" + 0.006*"artikel" + 0.006*"personen" + '
#   '0.006*"letzt" + 0.006*"maskenpflicht"')]
