# %%
import pandas as pd
import numpy as np
import pickle

# %%
df_main = pd.read_csv("tagi_art1.csv", delimiter = "|", header = None)

# %%
#remove columns without title, text or url
df_main = df_main.dropna(subset=[0])
df_main = df_main.dropna(subset=[4])
df_main = df_main.dropna(subset=[5])

# %%
#data cleaninig
df_main[3] = df_main[3].fillna("Agentur")
df_main[2] = df_main[2].str.replace("Publiziert: ", "")

# %%
#setting dates straight
time_indy = df_main[2]
time_indy = time_indy.str.split(",",expand=True)

df_main[2] = time_indy[0]
df_main[8] = time_indy[1]

df_main[2] = pd.to_datetime(df_main[2], format="%d.%m.%Y")
df_main[9] = df_main[2].dt.year

df_main = df_main[df_main[9] != 2021]
df_main = df_main.drop([9], axis = 1)
df_main = df_main.reset_index(drop = True)

# %%
# drop duplicates
df_main = df_main.drop_duplicates(keep = "last", ignore_index = True)

# %%
#setting up cateogries
catyy = df_main[5].str.split("/",expand=True)

catyy[8] = catyy[3]
catyy[9] = catyy[8].str.len()
catyy[9] = catyy[9].astype(int)

catyy[10] = np.where(catyy[9] < 20, catyy[3],"")

catyy[10].unique()
# Out:
# array(['', 'beizen-356087637501', 'schweiz', 'sonntagszeitung', 'wissen',
#        'zuerich', 'wirtschaft', 'ausland', 'kultur', 'leben', 'panorama',
#        'sport', 'news'], dtype=object)

# %%
catyy
# Out:
#           0  1                     2   \
# 0     https:     www.tagesanzeiger.ch
# 1     https:     www.tagesanzeiger.ch
# 2     https:     www.tagesanzeiger.ch
# 3     https:     www.tagesanzeiger.ch
# 4     https:     www.tagesanzeiger.ch
# ...      ... ..                   ...
# 1534  https:     www.tagesanzeiger.ch
# 1535  https:     www.tagesanzeiger.ch
# 1536  https:     www.tagesanzeiger.ch
# 1537  https:     www.tagesanzeiger.ch
# 1538  https:     www.tagesanzeiger.ch
#
#                                                      3   \
# 0           ein-jahr-fuer-die-wissenschaft-773527034087
# 1     wir-koennen-einem-91-jaehrigen-nicht-einfach-s...
# 2            wie-impfgegner-falsch-spielen-845211683571
# 3                 886-kerzen-fuer-886-tote-378812064884
# 4     impfkritiker-instrumentalisieren-tod-eines-91-...
# ...                                                 ...
# 1534                                             wissen
# 1535                                             wissen
# 1536                                             wissen
# 1537                                            ausland
# 1538                                            schweiz
#
#                                                      4   \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 1534  coronavirusdie-wichtigsten-fragen-und-antworte...
# 1535  coronavirusder-bundesrat-bleibt-trotz-kritik-a...
# 1536  coronaviruspatient-eins-liegt-im-spital-in-lugano
# 1537                                             europa
# 1538                                           standard
#
#                                           5         6         7   \
# 0                                       None      None      None
# 1                                       None      None      None
# 2                                       None      None      None
# 3                                       None      None      None
# 4                                       None      None      None
# ...                                      ...       ...       ...
# 1534                                   story  18759892      None
# 1535                                   story  11973554      None
# 1536                                   story  31145440      None
# 1537  weshalb-es-ausgerechnet-italien-trifft     story  29878048
# 1538        es-geht-einfach-alles-zu-schnell     story  13816331
#
#                                                      8   9        10
# 0           ein-jahr-fuer-die-wissenschaft-773527034087  43
# 1     wir-koennen-einem-91-jaehrigen-nicht-einfach-s...  88
# 2            wie-impfgegner-falsch-spielen-845211683571  42
# 3                 886-kerzen-fuer-886-tote-378812064884  37
# 4     impfkritiker-instrumentalisieren-tod-eines-91-...  82
# ...                                                 ...  ..      ...
# 1534                                             wissen   6   wissen
# 1535                                             wissen   6   wissen
# 1536                                             wissen   6   wissen
# 1537                                            ausland   7  ausland
# 1538                                            schweiz   7  schweiz
#
# [1539 rows x 11 columns]

# %%
df_main[9] = catyy[10]

# %%
#reorder columns
df_main = df_main[[0,1,2,8,3,4,5,9]]

# %%
df_main
# Out:
#                                                       0  \
# 0                         Ein Jahr für die Wissenschaft
# 1     «Wir können einem 91-Jährigen nicht einfach sa...
# 2                         Wie Impfgegner falsch spielen
# 3                               886 Kerzen für 886 Tote
# 4     Impfkritiker instrumentalisieren Tod eines 91-...
# ...                                                 ...
# 1534  Die wichtigsten Fragen und Antworten zum Coron...
# 1535  Panikmache um Coronavirus? Experten streiten sich
# 1536             Patient eins liegt im Spital in Lugano
# 1537             Weshalb es ausgerechnet Italien trifft
# 1538                 «Es geht einfach alles zu schnell»
#
#                                                       1          2       8  \
# 0     Von Beginn der Corona-Krise an agierte die For... 2020-12-31   21:16
# 1     Der oberste Schweizer Impfstratege Christoph B... 2020-12-31   19:10
# 2     Der Tod eines 91-Jährigen und seine Covid-Impf... 2020-12-31   16:11
# 3     Mitten in Zürich haben Aktivisten Lichter für ... 2020-12-30   23:15
# 4     Die Corona-Impfung habe im Kanton Luzern ein T... 2020-12-30   20:20
# ...                                                 ...        ...     ...
# 1534  Wie gefährlich ist das Virus? Muss man sich in... 2020-02-26   23:15
# 1535  Unterschätzt der Bundesrat das Virus? Oder wil...        NaT     NaN
# 1536  Nun hat die Schweiz den ersten Corona-Patiente...        NaT     NaN
# 1537  Italien zählt mehr Ansteckungen und Todesopfer...        NaT     NaN
# 1538  Die Kantone würden zu spät über aktuelle Entwi...        NaT     NaN
#
#                                   3  \
# 0                        Nik Walter
# 1                   Fabian Fellmann
# 2                        Nik Walter
# 3                     David Sarasin
# 4                       Fabian Renz
# ...                             ...
# 1534                Alexandra Bröhm
# 1535                 Christoph Lenz
# 1536  Sandro Benini und Yann Cherix
# 1537                  Oliver Meiler
# 1538                 Christoph Lenz
#
#                                                       4  \
# 0     Von Beginn der Corona-Krise an agierte die For...
# 1     Der oberste Schweizer Impfstratege Christoph B...
# 2     Der Tod eines 91-Jährigen und seine Covid-Impf...
# 3     Mitten in Zürich haben Aktivisten Lichter für ...
# 4     Die Corona-Impfung habe im Kanton Luzern ein T...
# ...                                                 ...
# 1534  Wie gefährlich ist das Virus? Muss man sich in...
# 1535  Unterschätzt der Bundesrat das Virus? Oder wil...
# 1536  Nun hat die Schweiz den ersten Corona-Patiente...
# 1537  Italien zählt mehr Ansteckungen und Todesopfer...
# 1538  Die Kantone würden zu spät über aktuelle Entwi...
#
#                                                       5        9
# 0     https://www.tagesanzeiger.ch/ein-jahr-fuer-die...
# 1     https://www.tagesanzeiger.ch/wir-koennen-einem...
# 2     https://www.tagesanzeiger.ch/wie-impfgegner-fa...
# 3     https://www.tagesanzeiger.ch/886-kerzen-fuer-8...
# 4     https://www.tagesanzeiger.ch/impfkritiker-inst...
# ...                                                 ...      ...
# 1534  https://www.tagesanzeiger.ch/wissen/coronaviru...   wissen
# 1535  https://www.tagesanzeiger.ch/wissen/coronaviru...   wissen
# 1536  https://www.tagesanzeiger.ch/wissen/coronaviru...   wissen
# 1537  https://www.tagesanzeiger.ch/ausland/europa/we...  ausland
# 1538  https://www.tagesanzeiger.ch/schweiz/standard/...  schweiz
#
# [1539 rows x 8 columns]

# %%
#settings up categories (ressorts) from topics
df_main[10] = ""
df_main[11] = df_main[9]
df_main[12] = ""


with open("ressorts_cat.bin", "rb") as data:
    ressorts = pickle.load(data)

df_main[11].replace(ressorts, inplace=True)

# %%
#delete unworkables
with open("to_delete.bin", "rb")as data:
    to_delete = pickle.load(data)
    
df_main = df_main[~df_main[9].isin(to_delete)]

# %%
df_main
# Out:
#                                                      0   \
# 0                         Ein Jahr für die Wissenschaft
# 1     «Wir können einem 91-Jährigen nicht einfach sa...
# 2                         Wie Impfgegner falsch spielen
# 3                               886 Kerzen für 886 Tote
# 4     Impfkritiker instrumentalisieren Tod eines 91-...
# ...                                                 ...
# 1534  Die wichtigsten Fragen und Antworten zum Coron...
# 1535  Panikmache um Coronavirus? Experten streiten sich
# 1536             Patient eins liegt im Spital in Lugano
# 1537             Weshalb es ausgerechnet Italien trifft
# 1538                 «Es geht einfach alles zu schnell»
#
#                                                      1          2       8   \
# 0     Von Beginn der Corona-Krise an agierte die For... 2020-12-31   21:16
# 1     Der oberste Schweizer Impfstratege Christoph B... 2020-12-31   19:10
# 2     Der Tod eines 91-Jährigen und seine Covid-Impf... 2020-12-31   16:11
# 3     Mitten in Zürich haben Aktivisten Lichter für ... 2020-12-30   23:15
# 4     Die Corona-Impfung habe im Kanton Luzern ein T... 2020-12-30   20:20
# ...                                                 ...        ...     ...
# 1534  Wie gefährlich ist das Virus? Muss man sich in... 2020-02-26   23:15
# 1535  Unterschätzt der Bundesrat das Virus? Oder wil...        NaT     NaN
# 1536  Nun hat die Schweiz den ersten Corona-Patiente...        NaT     NaN
# 1537  Italien zählt mehr Ansteckungen und Todesopfer...        NaT     NaN
# 1538  Die Kantone würden zu spät über aktuelle Entwi...        NaT     NaN
#
#                                  3   \
# 0                        Nik Walter
# 1                   Fabian Fellmann
# 2                        Nik Walter
# 3                     David Sarasin
# 4                       Fabian Renz
# ...                             ...
# 1534                Alexandra Bröhm
# 1535                 Christoph Lenz
# 1536  Sandro Benini und Yann Cherix
# 1537                  Oliver Meiler
# 1538                 Christoph Lenz
#
#                                                      4   \
# 0     Von Beginn der Corona-Krise an agierte die For...
# 1     Der oberste Schweizer Impfstratege Christoph B...
# 2     Der Tod eines 91-Jährigen und seine Covid-Impf...
# 3     Mitten in Zürich haben Aktivisten Lichter für ...
# 4     Die Corona-Impfung habe im Kanton Luzern ein T...
# ...                                                 ...
# 1534  Wie gefährlich ist das Virus? Muss man sich in...
# 1535  Unterschätzt der Bundesrat das Virus? Oder wil...
# 1536  Nun hat die Schweiz den ersten Corona-Patiente...
# 1537  Italien zählt mehr Ansteckungen und Todesopfer...
# 1538  Die Kantone würden zu spät über aktuelle Entwi...
#
#                                                      5        9  10  \
# 0     https://www.tagesanzeiger.ch/ein-jahr-fuer-die...
# 1     https://www.tagesanzeiger.ch/wir-koennen-einem...
# 2     https://www.tagesanzeiger.ch/wie-impfgegner-fa...
# 3     https://www.tagesanzeiger.ch/886-kerzen-fuer-8...
# 4     https://www.tagesanzeiger.ch/impfkritiker-inst...
# ...                                                 ...      ... ..
# 1534  https://www.tagesanzeiger.ch/wissen/coronaviru...   wissen
# 1535  https://www.tagesanzeiger.ch/wissen/coronaviru...   wissen
# 1536  https://www.tagesanzeiger.ch/wissen/coronaviru...   wissen
# 1537  https://www.tagesanzeiger.ch/ausland/europa/we...  ausland
# 1538  https://www.tagesanzeiger.ch/schweiz/standard/...  schweiz
#
#                  11 12
# 0
# 1
# 2
# 3
# 4
# ...             ... ..
# 1534   wissenschaft
# 1535   wissenschaft
# 1536   wissenschaft
# 1537  international
# 1538        schweiz
#
# [1538 rows x 11 columns]

# %%
df_main = df_main[[0,1,2,8,3,4,5,9, 7, 8, 10]]
df_main
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-d8c57d0e0752> in <module>
# ----> 1 df_main = df_main[[0,1,2,8,3,4,5,9, 7, 8, 10]]
#       2 df_main
#
# /home/adriana/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# /home/adriana/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# /home/adriana/snap/jupyter/common/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1314             if raise_missing:
#    1315                 not_found = list(set(key) - set(ax))
# -> 1316                 raise KeyError(f"{not_found} not in index")
#    1317
#    1318             not_found = key[missing_mask]
#
# KeyError: '[7] not in index'

# %%
df_main[13] = "tagi"
df_main[4] = df_main[4].str.replace("http\S+", "",regex = True)
df_main[4] = df_main[4].str.replace("Bild", "")
# Out:
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /snap/jupyter/6/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
df_main.to_csv("tagi_artikel.csv", header = None, sep = "|", index = False)

# %%
df_main
# Out:
#                                                      0   \
# 0                         Ein Jahr für die Wissenschaft
# 1     «Wir können einem 91-Jährigen nicht einfach sa...
# 2                         Wie Impfgegner falsch spielen
# 3                               886 Kerzen für 886 Tote
# 4     Impfkritiker instrumentalisieren Tod eines 91-...
# ...                                                 ...
# 1534  Die wichtigsten Fragen und Antworten zum Coron...
# 1535  Panikmache um Coronavirus? Experten streiten sich
# 1536             Patient eins liegt im Spital in Lugano
# 1537             Weshalb es ausgerechnet Italien trifft
# 1538                 «Es geht einfach alles zu schnell»
#
#                                                      1          2       8   \
# 0     Von Beginn der Corona-Krise an agierte die For... 2020-12-31   21:16
# 1     Der oberste Schweizer Impfstratege Christoph B... 2020-12-31   19:10
# 2     Der Tod eines 91-Jährigen und seine Covid-Impf... 2020-12-31   16:11
# 3     Mitten in Zürich haben Aktivisten Lichter für ... 2020-12-30   23:15
# 4     Die Corona-Impfung habe im Kanton Luzern ein T... 2020-12-30   20:20
# ...                                                 ...        ...     ...
# 1534  Wie gefährlich ist das Virus? Muss man sich in... 2020-02-26   23:15
# 1535  Unterschätzt der Bundesrat das Virus? Oder wil...        NaT     NaN
# 1536  Nun hat die Schweiz den ersten Corona-Patiente...        NaT     NaN
# 1537  Italien zählt mehr Ansteckungen und Todesopfer...        NaT     NaN
# 1538  Die Kantone würden zu spät über aktuelle Entwi...        NaT     NaN
#
#                                  3   \
# 0                        Nik Walter
# 1                   Fabian Fellmann
# 2                        Nik Walter
# 3                     David Sarasin
# 4                       Fabian Renz
# ...                             ...
# 1534                Alexandra Bröhm
# 1535                 Christoph Lenz
# 1536  Sandro Benini und Yann Cherix
# 1537                  Oliver Meiler
# 1538                 Christoph Lenz
#
#                                                      4   \
# 0     Von Beginn der Corona-Krise an agierte die For...
# 1     Der oberste Schweizer Impfstratege Christoph B...
# 2     Der Tod eines 91-Jährigen und seine Covid-Impf...
# 3     Mitten in Zürich haben Aktivisten Lichter für ...
# 4     Die Corona-Impfung habe im Kanton Luzern ein T...
# ...                                                 ...
# 1534  Wie gefährlich ist das Virus? Muss man sich in...
# 1535  Unterschätzt der Bundesrat das Virus? Oder wil...
# 1536  Nun hat die Schweiz den ersten Corona-Patiente...
# 1537  Italien zählt mehr Ansteckungen und Todesopfer...
# 1538  Die Kantone würden zu spät über aktuelle Entwi...
#
#                                                      5        9  10  \
# 0     https://www.tagesanzeiger.ch/ein-jahr-fuer-die...
# 1     https://www.tagesanzeiger.ch/wir-koennen-einem...
# 2     https://www.tagesanzeiger.ch/wie-impfgegner-fa...
# 3     https://www.tagesanzeiger.ch/886-kerzen-fuer-8...
# 4     https://www.tagesanzeiger.ch/impfkritiker-inst...
# ...                                                 ...      ... ..
# 1534  https://www.tagesanzeiger.ch/wissen/coronaviru...   wissen
# 1535  https://www.tagesanzeiger.ch/wissen/coronaviru...   wissen
# 1536  https://www.tagesanzeiger.ch/wissen/coronaviru...   wissen
# 1537  https://www.tagesanzeiger.ch/ausland/europa/we...  ausland
# 1538  https://www.tagesanzeiger.ch/schweiz/standard/...  schweiz
#
#                  11 12    13
# 0                       tagi
# 1                       tagi
# 2                       tagi
# 3                       tagi
# 4                       tagi
# ...             ... ..   ...
# 1534   wissenschaft     tagi
# 1535   wissenschaft     tagi
# 1536   wissenschaft     tagi
# 1537  international     tagi
# 1538        schweiz     tagi
#
# [1538 rows x 12 columns]
